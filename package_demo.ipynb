# %%
import pandas as pd
from data_analyzer import DataAnalyzer

# %%
data = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv',
                   sep=',')

# %%
data_analyzer = DataAnalyzer(data)

# %%
data_analyzer.get_data_structure_summary()
# Out:
# ------------------------------------------------------------
# Data Shape
# ------------------------------------------------------------
# 891 Records & 12 Features
#
# ------------------------------------------------------------
# Duplicate Records
# ------------------------------------------------------------
# 0 (0.0 %)
#
# ------------------------------------------------------------
# Top 5 Rows (Transpose)
# ------------------------------------------------------------
#                                    0                                                  1                       2                                             3                         4
# PassengerId                        1                                                  2                       3                                             4                         5
# ...

# %%
data_analyzer.get_categorical_features_summary()
# Out:
# ------------------------------------------------------------
# Feature: Name
# ------------------------------------------------------------
#
# Data Type:
#  object
#
# Total Value Count (Excluding Missing Values):
#  891
#
# Unique Value Count (Excluding Missing Value):
#  891
#
# Missing Values:
#  0 (0.0%)
#
# Data Distribution:
#                                           count  proportion
# Braund, Mr. Owen Harris                       1         0.0
# Boulos, Mr. Hanna                             1         0.0
# Frolicher-Stehli, Mr. Maxmillian              1         0.0
# Gilinski, Mr. Eliezer                         1         0.0
# Murdlin, Mr. Joseph                           1         0.0
# ...                                         ...         ...
# Kelly, Miss. Anna Katherine "Annie Kate"      1         0.0
# McCoy, Mr. Bernard                            1         0.0
# Johnson, Mr. William Cahoone Jr               1         0.0
# ...

# %%
data_analyzer.get_numeric_features_summary()
# Out:
# ------------------------------------------------------------
# Feature: Age
# ------------------------------------------------------------
#
# unique       88
# mean         29.6991
# median       28.0
# minimum      0.42
# maximum      80.0
# range        79.58
# stdev        14.5163
# CV           0.4888
# q1           20.125
# q2           28.0
# q3           38.0
# iqr          17.875
# lower_bound  -6.6875
# upper_bound  64.8125
# skewness     0.3883
# kurtosis     0.1686
# dtype        float64
#
# Data Distribution
# ------------------------------------------------------------
# Feature: Fare
# ------------------------------------------------------------
#
# unique       248
# mean         32.2042
# median       14.4542
# minimum      0.0
# maximum      512.3292
# range        512.3292
# stdev        49.6655
# CV           1.5422
# q1           7.9104
# q2           14.4542
# q3           31.0
# iqr          23.0896
# lower_bound  -26.724
# upper_bound  65.6344
# ...

# %%
data_analyzer.plot_correlation_matrix()

# %%
data_analyzer.plot_chi_square_result()

# %%
data_analyzer.plot_numeric_vs_numeric()

# %%
data_analyzer.plot_categorical_vs_categorical()

# %%
data_analyzer.plot_categorical_vs_numeric()

# %%
_ = data_analyzer.plot_mutual_information('Survived')

# %%
_ = data_analyzer.get_vif()
# Out:
#        feature       vif
# 0          Age  2.844611
# 1  PassengerId  2.813867
# 2         Fare  1.538800
# 3        Parch  1.503980
# 4        SibSp  1.468774
